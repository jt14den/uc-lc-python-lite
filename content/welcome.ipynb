# %% [markdown]
# # Welcome to JupyterLite
#
# This is a browser-based Python environment — no installation required. Everything runs directly in your browser.
#
# ---
#
# ## Your setup
#
# The lesson data is already here. In the file browser on the left you'll see a `data/` folder containing 12 CSV files (Chicago Public Library circulation data, 2011–2022) plus two pre-built pickle files.
#
# You don't need to download or unzip anything. File paths in the lesson like `'data/2011_circ.csv'` will work as-is.
#
# ---
#
# ## Quick check
#
# Run the cell below to confirm everything is working.

# %%
import pandas as pd
import glob

files = sorted(glob.glob('data/*.csv'))
print(f'Found {len(files)} CSV files:')
for f in files:
    print(' ', f)

df = pd.read_csv(files[0])
print(f'\nFirst file has {len(df):,} rows and {len(df.columns)} columns.')
df.head(3)

# %% [markdown]
# ---
#
# ## One thing to know
#
# JupyterLite doesn't support shell commands. Lines starting with `!` (like `!pip install` or `!ls`) won't work here. All the packages you need for this lesson — `pandas`, `matplotlib`, `numpy`, `seaborn`, `plotly` — are already installed.
#
# ---
#
# ## Starting the lesson
#
# Follow along at: **https://librarycarpentry.github.io/lc-python-intro/**
#
# To create a new notebook: click the **+** button at the top of the file browser, then choose **Python (XPython)**.
